# %% [markdown]
# <a href="https://colab.research.google.com/github/Hozaifabinumair2011/Vscode/blob/main/Asymptotic_notation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def abc(n):
  iteration= 0
  print(n)
  iteration=iteration +1
  print(iteration)
abc(10)
abc(200)
# Out:
# 10
# 1
# 200
# 1

# %%
def abc(n):
  iteration= 0
  for i in range(1,n+1):
    iteration=iteration +1
  print(iteration)
abc(10)
abc(200)
# Out:
# 10
# 200

# %%
def abc(n):
  iteration= 0
  for i in range(0,n):
    for j in range(0,n):
      print("*",end="")
      iteration=iteration +1
    print("")
  print(n,iteration)
abc(10)
abc(200)
# Out:
# **********
# **********
# **********
# **********
# **********
# **********
# **********
# **********
# **********
# **********
# 10 100
# ********************************************************************************************************************************************************************************************************
# ********************************************************************************************************************************************************************************************************
# ********************************************************************************************************************************************************************************************************
# ********************************************************************************************************************************************************************************************************
# ...
