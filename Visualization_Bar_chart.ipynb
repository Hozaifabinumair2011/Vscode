# %% [markdown]
# <a href="https://colab.research.google.com/github/Hozaifabinumair2011/Vscode/blob/main/Visualization_Bar_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
names = ['China','India','United States','Indonesia','Brazil','Pakistan','Bangladesh','Nigeria','Mexico','Philippines']
pop_grow = (25,85,75,65,80,45,63,29,33,31) # Added two values to match the length of 'names'
plt.figure(figsize=(15,9))
plt.bar(names,pop_grow,width=0.6)
plt.xlabel('Country')
plt.ylabel('Population Growth (Millions)')
plt.title("Top 10 Countries with the Biggest Population Growth from 1952 to 2007")
plt.xticks(rotation=45)

#zip join x and y coords in pair
for x,y in zip(names,pop_grow):
  label = "{:.2f}".format(y)
  plt.annotate(label,(x,y),textcoords="offset points",xytext=(0,10),ha='center')
plt.show()
